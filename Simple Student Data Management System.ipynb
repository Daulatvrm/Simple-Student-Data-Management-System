# %% [markdown]
# # Simple Student Management Data System

# %%
#This is a simple student data management programm in python
#Creating a student class

class Student:
    
    #constractor
    
    def __init__(self, name,  rollno, english, hindi, math, science, sanskrit):
        
        self.rollno = rollno
        self.name = name
        self.english = english
        self.hindi = hindi
        self.math = math
        self.science = science
        self.sanskrit = sanskrit
        
        
    #function to accept and append new student
    
    def accept(self,Name, Rollno,  english, hindi, math, science, sanskrit):
        
        std_obj = Student(Name, Rollno, english, hindi, math, science, sanskrit)
        lst.append(std_obj)
        
    def display(self,std_obj):
        
        print("\nName ->",std_obj.name)
        print("Roll No ->",std_obj.rollno)
        print("English ->",std_obj.english)
        print("Hindi ->",std_obj.hindi)
        print("Maths ->",std_obj.math)
        print("Science ->",std_obj.science)
        print("Sanskrit ->",std_obj.sanskrit)
        print("--" * 20)
        print("Total Marks :", std_obj.english + std_obj.hindi + std_obj.math + std_obj.science +std_obj.sanskrit )
        print("Percentage :",round((std_obj.english + std_obj.hindi + std_obj.math + std_obj.science +std_obj.sanskrit)/500*100,2))
        print("\n")
        print("**" * 20)
        
        
                
    # Search Function
    def search(self, roll_num):
        
        for i in range(lst.__len__()):
            if(lst[i].rollno == roll_num):
                return i
    
    # Delete Function
    def delete(self, roll_num):
        i = obj.search(roll_num)
        del lst[i]
    
    #Update Function
    def update(self,roll_num):
        
        i = obj.search(roll_num)
        new_name  = str(input("Enter New Name :  "))
        lst[i].name=new_name
        
        print("\n Recored updated successfully.")
        print(lst[i].name, lst[i].rollno,lst[i].english,lst[i].hindi,lst[i].math,lst[i].science,lst[i].sanskrit)
      
        
#Creating Empty List
lst = []

#An object of Student class
obj = Student('',0,0,0,0,0,0)

print("\n Operation used")
print("\n1.Show Total Number of Students\n2.Display Student Details\n3.Search Details of a Student\n4.Delete Details of Student\n5.Update Student Details\n6.Exit")


obj.accept('Ram',101,45,50,40,70,80)
obj.accept('Shyam',102,28,47,75,89,36)
obj.accept('Daulat Verma',103,65,40,78,37,41)
obj.accept('Anil Sharma',104,85,52,92,39,28)

#Taking input from user to perform an operation
choice = int(input("\nEnter your choice :"))

if(choice == 1):
    print("Total Number of student",lst.__len__())
        
elif (choice == 2):
    for i in range(lst.__len__()):
        obj.display(lst[i])
        
elif (choice == 3):
    roll_num = int(input("Enter Roll No."))
    item = obj.search(roll_num)
    obj.display(lst[item])

elif(choice == 4):
    
    roll_num = int(input("Enter Roll No."))
    obj.delete(roll_num)
    
    print("Record deleted successfully")
    print("Available Records : ", lst.__len__())
    
elif(choice == 5):
    
    roll_num = int(input("Enter Roll No."))
    obj.update(roll_num)
else:
    print("Thank You..")
# Out:
#  Operation used
#
# 1.Show Total Number of Students
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete Details of Student
# 5.Update Student Details
# 6.Exit
#
# Enter your choice :2
#
# Name -> Ram
# Roll No -> 101
# English -> 45
# Hindi -> 50
# Maths -> 40
# Science -> 70
# Sanskrit -> 80
# ----------------------------------------
# Total Marks : 285
# Percentage : 57.0
#
#
# ****************************************
#
# Name -> Shyam
# Roll No -> 102
# English -> 28
# Hindi -> 47
# Maths -> 75
# Science -> 89
# Sanskrit -> 36
# ----------------------------------------
# Total Marks : 275
# Percentage : 55.0
#
#
# ****************************************
#
# Name -> Daulat Verma
# Roll No -> 103
# English -> 65
# Hindi -> 40
# Maths -> 78
# Science -> 37
# Sanskrit -> 41
# ----------------------------------------
# Total Marks : 261
# Percentage : 52.2
#
#
# ****************************************
#
# Name -> Anil Sharma
# Roll No -> 104
# English -> 85
# ...
