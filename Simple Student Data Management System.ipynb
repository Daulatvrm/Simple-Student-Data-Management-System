# %% [markdown]
# # Simple Student Data System

# %%
#This is a simple student data management programm in python
#Creating a student class

class Student:
    
    #constractor
    
    def __init__(self, name,  rollno, m1, m2):
        
        self.rollno = rollno
        self.name = name
        self.m1 = m1
        self.m2 = m2
        
    #function to accept and append new student
    
    def accept(self,Name, Rollno,  Marks1, Marks2):
        
        ob = Student(Name, Rollno, Marks1, Marks2)
        ls.append(ob)
        
    def display(self,ob):
        
        print("Name ->",ob.name)
        print("Roll No ->",ob.rollno)
        print("Marks1 ->",ob.m1)
        print("Marks2 ->",ob.m2)
        print("\n")
        
                
    # Search Function
    def search(self, rn):
        
        for i in range(ls.__len__()):
            if(ls[i].rollno == rn):
                return i
    
    # Delete Function
    def delete(self, rn):
        i = obj.search(rn)
        del ls[i]
    
    #Update Function
    def update(self,rn):
        
        i = obj.search(rn)
        new_name  = str(input("Enter New Name :  "))
        ls[i].name=new_name
        
        print("\n Recored updated successfully.")
        print(ls[i].name, ls[i].rollno,ls[i].m1,ls[i].m2)
      
        
#Creating Empty List
ls = []

#An object of Student class
obj = Student('',0,0,0)

print("\n Operation used")
print("\n1.Show Total Number of Students\n2.Display Student Details\n3.Search Details of a Student\n4.Delete Details of Student\n5.Update Student Details\n6.Exit")


obj.accept('Ram',101,45,50)
obj.accept('Shyam',102,28,47)
obj.accept('Daulat Verma',103,65,40)
obj.accept('Anil Sharma',104,85,52)

ch = int(input("Enter your choice :"))

if(ch == 1):
    print("Total Number of student",ls.__len__())
        
elif (ch == 2):
    for i in range(ls.__len__()):
        obj.display(ls[i])
        
elif (ch == 3):
    rn = int(input("Enter Roll No."))
    s = obj.search(rn)
    obj.display(ls[s])

elif(ch == 4):
    
    rn = int(input("Enter Roll No."))
    obj.delete(rn)
    
    print("Record deleted successfully")
    print("Available Records : ", ls.__len__())
    
elif(ch == 5):
    
    rn = int(input("Enter Roll No."))
    obj.update(rn)
else:
    print("Thank You..")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-6cb8434bad47> in <module>
#      53
#      54 #An object of Student class
# ---> 55 obj = Student(self)
#      56
#      57 print("\n Operation used")
#
# NameError: name 'self' is not defined
